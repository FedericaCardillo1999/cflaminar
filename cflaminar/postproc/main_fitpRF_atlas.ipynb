# %% [markdown]
# #  pRF analysis on visual cortex (partial volume), on Gray Matter (not layered)

# %%
# %reload_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from prfpy.stimulus import PRFStimulus2D
from prfpy.model import Iso2DGaussianModel
from prfpy.fit import Iso2DGaussianFitter, Fitter, Extend_Iso2DGaussianFitter
from prfpy.rf import gauss2D_iso_cart
import os
import yaml
import scipy.io
from marcus_prf_eg.utils import *
from marcus_prf_eg.plot_functions import * #Graph tools provided by Marcus Daghlian (https://github.com/mdaghlian)

#Adapted from initial pRF fitting tutorial provided by Marcus Daghlian (https://github.com/mdaghlian)

# %%
MAIN_PATH=os.getenv("DERIVATIVES")

#USER INPUT:
subject='sub-001'
depth='GM' #Gray matter (GM) or layer's depth (e.g. 0.0 for white matter surface, 1.0 for pial surface) 
space='fsnative'
project='CFLamUp'
denoising='nordic'
atlas = 'manual' # manual delineation ('manual') or benson atlas ('benson')
dm_filename='design_task-ret.mat' #should be placed in the 'derivatives/pRFM'folder; same dm for all subjects'
prf_settings_filename='fit_settings_prf_pilot1.yml' #should be placed in the 'derivatives/pRFM'folder; same prf settings for all subjects'

if atlas=='benson':
    rois = ['V1', 'V2', 'V3', 'V4', 'LO1', 'LO2','V3a', 'V3b']
elif atlas =='manual':
    rois = ['V1', 'V2', 'V3', 'V4', 'LO1', 'LO2']

# %% [markdown]
# ## Load design matrix

# %%
dm =scipy.io.loadmat(f'{MAIN_PATH}/pRFM/{dm_filename}')['stim'] #same design matrix for all subjects
# You can see we have a binarized matrix, of a bar moving across the screen...
fig = plt.figure()
rows = 10
cols = 10
fig.set_size_inches(15,15)
for i in range(100):
    ax = fig.add_subplot(rows, cols, i+1)
    ax.imshow(dm[:,:,i], vmin=0, vmax=1)
    ax.axis('off')

dm=dm[:,:,5:215]
dm.shape
# Out:
# (100, 100, 210)

# %% [markdown]
# When setting up the model it is important to be clear what settings you are using, and make it easily reproducible. To that end it is recommended that you keep all the specific values in a .yml file, which can be loaded in (rather than hard coding "magic" numbers in your script)

# %%
# Load the settings from .yml file
prf_settings_file = f'{MAIN_PATH}/pRFM/{fit_settings_prf_pilot1}' #same prf settings for all subjects
with open(prf_settings_file) as f:
    prf_settings = yaml.safe_load(f)

# %% [markdown]
# # Creating stimulus object
# Before fitting the PRFs we need to create the design matrix, i.e., a binary representation of the stimulus. The stimuli used in this example is a bar moving across the visual field (see eg_screen_shot.png for an example).
#
# prfpy needs the design matrix to be a numpy array of n x n x time points. Each time point will correspond to the timepoints in the fMRI sequence. n is the number of pixels in the design matrix.
#
# Going from the stimulus shown in the scanner to the n x n x timepoints in the design matrix involves 3 steps:
#
# [1] Binarize the stimulus (where there is stimulus=1, no stimulus=0)
#
# [2] Make it square (i.e., cut off the unstimulated part of the screen). This is because typically the stimuli are presented in a circular aperture; therefore including the full rectangle of the screen is unnecessary.
#
# [3] Downsample the stimulus (so that it can run faster, e.g., from 1080 x 1080 to 100 x 100)
#
# If you want you could also just recreate the design matrix from same parameters you used to make the stimulus (i.e., defining bar/wedge position over time). This doesn't matter

# %%
# Now we need to enter the design matrix in a way that prfpy can read it. 
# We do this using the PRFStimulus2D object
# Information we need
# -> Screen size (height), and distance (to the eye)
# This is so that we can convert into degrees of visual angle (dov)
# -> TR: This is so that we know the time (in s), of each 'frame' / pt in the time series
# E.g( If we have 225 time points. The total length of scan is TR * 225 (1.5*225) 
prf_stim = PRFStimulus2D(
    screen_size_cm=prf_settings['screen_size_cm'],          # height of the screen (i.e., the diameter of the stimulated region)
    screen_distance_cm=prf_settings['screen_distance_cm'],  # Distance of screen to eye
    design_matrix=dm,                                   # dm (npix x npix x time_points)
    TR=prf_settings['TR'],                                  # TR
    )
print(f'Screen size in degrees of visual angle = {prf_stim.screen_size_degrees}')

# If for some reason you do not have the original dimensions, but you do have the dov, you can use this calculator:
# https://elvers.us/perception/visualAngle/ to make up some values for screen_size and distance, which will work...
# Out:
# Screen size in degrees of visual angle = 11.450128652841203

# %% [markdown]
# # Preparing the data
# The next step is to prepare the fMRI time series. The format that prfpy wants is a numpy array of number of
# For prfpy the time series needs to be 2D numpy array, where the first dimension is units (i.e., voxels or vertices) and the second dimension is time. The number of timepoints in your data should match the number in the design matrix (here it is 225).
#
# A couple of notes:
#
# [*] Preprocessing? I assume that all of the important stuff, i.e., denoising, removing confounds has been done already. This is just to prepare the data for prfpy specifically.
#
# [*] Averaging? The more runs (i.e., repetitions of the same stimulus) you average over, the less noise, and the better the prf estimates will be. You can fit on a single run (especially in high SNR situations, e.g., using 7T) without averaging, but quality will be less good.
#
# [*] Voxels or vertices? In principle you can fit any time series data with a prf model. I always fit using vertices, with the data sampled to the cortical surface. This will make visualisations much easier, if you want to plot your PRF parameters on the cortical surface. You can then use tools like pycortex
#
# [*] Percent signal change? Again, in principle you can fit any time series data with a prf model. I use percent signal change, with the baseline set to 0. Why do this? It makes it easier to compare timeseries across voxels when the units are the same (as opposed to the arbitrary values you get out of "raw" fMRI data). Also, if you do *not* set the baseline value to 0 (i.e. the amplitude of the prf model when there is 0 stimulation) you need to fit it for each vertex. There are also added complications when you have PRFs with inhibitory components. Another option is to use z-scoring rather than psc.
#
# [*] Include first part of timeseries? Some people will remove the first (e.g.,5) timepoints of the fMRI data. This is because perhaps it takes a couple of seconds for the subject to get used to the scanner / stimulus or maybe there are startup effects... If you want to do this, make sure you make the corresponding changes to the design matrix.
#
# ### Steps, using example data
# I have provided some example time series data for 100 vertices
#
# [1] Convert to percent signal change
#
# [2] Set the median value during the baseline condition (i.e., when there is no stimulation) to zero
#
# See functions in marcus_prf_eg/utils for more details

# %% [markdown]
# Example, raw time series. You can already see the peaks corresponding to the bar passes.
# But the units are arbitrary... We want to change it to be in psc
# Also we can improve the SNR by averaging over the 2 runs...

# %%
# # Do the averaging and baselining...
# # During the first 20 time points, there is NO stimulation. So we use this to set the baseline
# psc_avg_ts = raw_ts_to_average_psc(
#     raw_ts=[run1, run2],        # Enter the runs as a list of np.ndarrays
#     baseline=19,                # The first 20 time points, there is NO stimulation. So we use this to set the baseline
# )
#
# print('''Now we can see what the the time series looks like after psc, baselining and averaging:''')
# psc_avg_ts=np.load('/Users/mayra/PycharmProjects/Github/marcus_prfpy_tutorial/pilot1/ses-1/sub-001_ses-1_task-ret_hemi-LR_desc-avg_bold.npy').T[:,:]
psc_avg_ts_full=np.load(f'{MAIN_PATH}/pRFM/{subject}/ses-1/{denoising}/{subject}_ses-1_task-ret_hemi-LR_desc-avg_bold_{depth}.npy').T[:,:]
print(psc_avg_ts_full.shape)

if psc_avg_ts_full.shape[1]>225:
    psc_avg_ts_full=psc_avg_ts_full[:,:225]

psc_avg_ts_full.shape
# Out:
# (281741, 210)
# (281741, 210)

# %%
import cortex
import cortex.polyutils
#select voxels in selected ROIs



if subject=='fsaverage':
    fs_dirPATH='/Volumes/May_fMRI/Inzicht_CFM/derivatives/freesurfer'
else:
    fs_dirPATH=f'{MAIN_PATH}/freesurfer'

# %%
# In order to get the number of vertices in this subject's cortical surface
# we have to load in their surfaces and get the number of points in each
surfs = [cortex.polyutils.Surface(*d)
         for d in cortex.db.get_surf(subject, "fiducial")]

# %% [markdown]
# ## Mask voxels outside visual cortex based on Benson Atlas for efficiency

# %%
# First we need to import the surfaces for this subject
numel_left = surfs[0].pts.shape[0]
numel_right = surfs[1].pts.shape[0]
numel = numel_left + numel_right

idx_rois1, idx_vls1 = cortex.freesurfer.get_label(subject, label='benson14_eccen-0001',
                                        fs_dir=fs_dirPATH,
                                        hemisphere=('lh', 'rh'),
                                        verbose=True)

idx_rois4, idx_vls4 = cortex.freesurfer.get_label(subject, label='benson14_varea-0001',
   fs_dir=fs_dirPATH,
  hemisphere=('lh', 'rh'),
  verbose=True)

#plot Benson atlas
rois_list = []
if atlas=='benson':
  rois_list = np.array([['V1', 'V2', 'V3', 'V4', 'LO1', 'LO2', 'V3a', 'V3b'], [1, 2, 3, 4, 7, 8, 11, 12]])
elif atlas =='manual':
  rois_list = np.array([['V1', 'V2', 'V3', 'V4', 'LO1', 'LO2'], [1, 2, 3, 4, 7, 8]])

rois_mask=cortex.Vertex.empty(subject)
rois_idx=cortex.Vertex.empty(subject)
for r in range(rois.__len__()):
    roi_idx = np.where(rois[r] == rois_list[0, :])
    #roi_verts = np.array(np.where(idx_vls4 == int(rois_list[1, roi_idx])))[0]
    roi_verts = np.where(np.logical_and(idx_vls4 == int(rois_list[1, roi_idx][0][0]),idx_vls1<10))[0]
    rois_mask.data[roi_verts]=1
    rois_idx.data[roi_verts]=roi_verts

psc_avg_ts=psc_avg_ts_full[rois_mask.data==1]
psc_avg_ts_vx=rois_idx.data[rois_mask.data==1]
psc_avg_ts.shape
psc_avg_ts_full[rois_mask.data!=1]=0
# Out:
# looking for ['/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/freesurfer/sub-001/label/lh.benson14_eccen-0001.label', '/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/freesurfer/sub-001/label/rh.benson14_eccen-0001.label']
# looking for ['/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/freesurfer/sub-001/label/lh.benson14_varea-0001.label', '/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/freesurfer/sub-001/label/rh.benson14_varea-0001.label']

# %%
np.where(idx_rois1!=idx_rois4[:])
int(rois_list[1, roi_idx][0][0])
# Out:
# 12

# %% [markdown]
# # Creating the (gaussian) model
# Now we can create the PRF model. The simplest is the 2D isometric (i.e., circular) gaussian
#
#
# The Iso2DGaussianModel class is used to create an 2D gaussian model instance.
# There are a few parameters you can set. See below (copied from prfpy documentation), for details.
# Note you can also fit the HRF

# %%
'''    
    """__init__ for Iso2DGaussianModel
    constructor, sets up stimulus and hrf for this Model
    Parameters
    ----------
    stimulus : PRFStimulus2D
        Stimulus object specifying the information about the stimulus,
        and the space in which it lives.
    hrf : string, list or numpy.ndarray, optional
        HRF shape for this Model.
        Can be 'direct', which implements nothing (for eCoG or later convolution),
        a list or array of 3, which are multiplied with the three spm HRF basis functions,
        and an array already sampled on the TR by the user.
        (the default is None, which implements standard spm HRF)
    filter_predictions : boolean, optional
        whether to high-pass filter the predictions, default False
    filter_type, filter_params : see timecourse.py
    normalize_RFs : whether or not to normalize the RF volumes (generally not needed).
'''
gauss_model = Iso2DGaussianModel(
    stimulus=prf_stim,                                  # The stimulus we made earlier
    hrf=prf_settings['hrf']['pars'],                        # These are the parameters for the HRF that we normally use at Spinoza (with 7T data). (we can fit it, this will be done later...)
    filter_predictions = prf_settings['filter_predictions'],# Do you want to filter the predictions? (depends what you did to the data, try and match it... default is not to do anything)
    normalize_RFs= prf_settings['normalize_RFs'],           # Normalize the volume of the RF (so that RFs w/ different sizes have the same volume. Generally not needed, as this can be solved using the beta values i.e.,amplitude)
    )

# %% [markdown]
# # Creating the gaussian fitter
# Now we need to make a fitter, to load in the data

# %%
gauss_fitter=Iso2DGaussianFitter(
    data=psc_avg_ts[:,:],    # time series
    model=gauss_model,                   # model (see above)
    #n_jobs=prf_settings['n_jobs'],  # number of jobs to use in parallelization
    n_jobs=1,  # number of jobs to use in parallelization
    )

# %% [markdown]
# ## Gaussian grid fit
# The first stage is the 'grid fit'
# Here we make a "grid" of possible PRF models, (different locations: polar angle, eccentricity, as well as sizes)

# %%
max_eccentricity = round(prf_stim.screen_size_degrees/2) # It doesn't make sense to look for PRFs which are outside the stimulated region
grid_nr = prf_settings['grid_nr'] # Size of the grid (i.e., number of possible PRF models). Higher number means that the grid fit will be more exact, but take longer...
eccs    = np.linspace(0.1, max_eccentricity*1.5, grid_nr)  # Squared because of cortical magnification, more efficiently tiles the visual field...
sizes   =  np.linspace(0.1, max_eccentricity, int(grid_nr))   # Possible size values (i.e., sigma in gaussian model)
polars  = np.linspace(0, 2*np.pi, int(grid_nr))              # Possible polar angle coordinates

# We can also fit the hrf in the same way (specifically the derivative)
# -> make a grid between 0-10 (see settings file)
hrf_1_grid = np.linspace(prf_settings['hrf']['deriv_bound'][0], prf_settings['hrf']['deriv_bound'][1], 10)
#hrf_1_grid = np.array([1.0]) #fixed
# We generally recommend to fix the dispersion value to 0
hrf_2_grid = np.array([0.0]) #fixed

# If you don't want to do any hrf fitting - set both to be NONE (uncomment below)
# hrf_1_grid = None
# hrf_2_grid = None

# %% [markdown]
# We also want to put some boundaries on possible values
# We set the baseline to 0, so we want to fix that here. 'fixed_grid_baseline=0'
# In addition, there is the amplitude parameter (which scales the response).
# We want to put an upper limit for this too, so that we don't get strange responses

# %% [markdown]
# ## Stage 1: grid search

# %%
# Amplitude bounds for gauss grid fit - set [min, max]
gauss_grid_bounds = [[prf_settings['prf_ampl'][0],prf_settings['prf_ampl'][1]]]

gauss_fitter.grid_fit(
    ecc_grid=eccs,
    polar_grid=polars,
    size_grid=sizes,
    hrf_1_grid=hrf_1_grid,
    hrf_2_grid=hrf_2_grid,
    verbose=False,
    n_batches=prf_settings['n_batches'],               # The grid fit is performed in parallel over n_batches of units.Batch parallelization is faster than single-unit parallelization and of sequential computing.
    fixed_grid_baseline=prf_settings['fixed_grid_baseline'], # Fix the baseline? This makes sense if we have fixed the baseline in preprocessing
    grid_bounds=gauss_grid_bounds
    )

print(f'Mean rsq = {np.nanmean(gauss_fitter.gridsearch_r2):.3f}')
print(f'Max rsq = {np.nanmax(gauss_fitter.gridsearch_r2):.3f}')
print(np.where(gauss_fitter.gridsearch_r2==np.nanmax(gauss_fitter.gridsearch_r2)))

# Plot the location...
plt.scatter(gauss_fitter.gridsearch_params[:,0], gauss_fitter.gridsearch_params[:,1],marker='o', s=2)
plt.xlim(-5,5)
plt.ylim(-5,5)
# Out:
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/model.py:315: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if current_hrf == 'direct':
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: divide by zero encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: invalid value encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:450: RuntimeWarning: invalid value encountered in multiply
#   slopes[..., np.newaxis] *
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: divide by zero encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: invalid value encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:450: RuntimeWarning: invalid value encountered in multiply
#   slopes[..., np.newaxis] *
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: divide by zero encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: invalid value encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:450: RuntimeWarning: invalid value encountered in multiply
#   slopes[..., np.newaxis] *
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: divide by zero encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: invalid value encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:450: RuntimeWarning: invalid value encountered in multiply
#   slopes[..., np.newaxis] *
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: divide by zero encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: invalid value encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:450: RuntimeWarning: invalid value encountered in multiply
#   slopes[..., np.newaxis] *
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: divide by zero encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:445: RuntimeWarning: invalid value encountered in divide
#   slopes = (np.dot(vox_data-fixed_grid_baseline, predictions.T)) / (square_norm_preds)
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/fit.py:450: RuntimeWarning: invalid value encountered in multiply
#   slopes[..., np.newaxis] *
# Mean rsq = 0.228
# Max rsq = 0.757
# (array([14569]),)
# (-5.0, 5.0)

# %% [markdown]
# ## Stage 2: Gaussian Iterative Fit - nohrf
# Now we can do the iterative fit. This takes the best fitting grid (from the above stage), and iteratively tweaks the parameters until the best fit is founds.
# This takes a bit longer than the grid fit. We also need to setup the bounds for all the parameters.

# %%
if prf_settings['constraints']==True:
    g_constraints = [] # uses trust-constraint (which is slower)
else:
    g_constraints = None # uses l-BFGS (which is faster)

gauss_iter_bounds = [
    (-1.5*max_eccentricity, 1.5*max_eccentricity),          # x bound
    (-1.5*max_eccentricity, 1.5*max_eccentricity),          # y bound
    (1e-1, 1.5*max_eccentricity),                             # prf size bounds
    (prf_settings['prf_ampl'][0],prf_settings['prf_ampl'][1]),      # prf amplitude
    (prf_settings['bold_bsl'][0],prf_settings['bold_bsl'][1]),      # bold baseline (fixed)
    (prf_settings['hrf']['deriv_bound'][0], prf_settings['hrf']['deriv_bound'][1]), # hrf_1 bound
    (prf_settings['hrf']['pars'][2], prf_settings['hrf']['pars'][2]), # hrf_2 bound
]

gauss_fitter.iterative_fit(
    rsq_threshold=prf_settings['rsq_threshold'],    # Minimum variance explained. Puts a lower bound on the quality of PRF fits. Any fits worse than this are thrown away...
    verbose=False,
    bounds=gauss_iter_bounds,       # Bounds (on parameters)
    constraints=g_constraints, # Constraints
    xtol=float(prf_settings['xtol']),     # float, passed to fitting routine numerical tolerance on x
    ftol=float(prf_settings['ftol']),     # float, passed to fitting routine numerical tolerance on function
    )

# Rescue vxs where iterative fit was worse than grid fit
rsq_mask=np.ones(gauss_fitter.rsq_mask.shape) #this one is based on grid fit
rsq_mask[gauss_fitter.iterative_search_params[:,7]<prf_settings["rsq_threshold"]]=False
checkrsq=np.where(np.logical_and(gauss_fitter.gridsearch_params[:,-1]>gauss_fitter.iterative_search_params[:,-1],gauss_fitter.iterative_search_params[:,-1]!=0))
gauss_fitter.iterative_search_params[checkrsq,:]=gauss_fitter.gridsearch_params[checkrsq,:]
# Out:
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# /Users/mayra/.local/lib/python3.9/site-packages/nilearn/glm/__init__.py:55: FutureWarning: The nilearn.glm module is experimental. It may change in any future release of Nilearn.
#   warn('The nilearn.glm module is experimental. '
# /Users/mayra/.local/lib/python3.9/site-packages/nilearn/glm/__init__.py:55: FutureWarning: The nilearn.glm module is experimental. It may change in any future release of Nilearn.
#   warn('The nilearn.glm module is experimental. '
# /Users/mayra/.local/lib/python3.9/site-packages/nilearn/glm/__init__.py:55: FutureWarning: The nilearn.glm module is experimental. It may change in any future release of Nilearn.
#   warn('The nilearn.glm module is experimental. '
# /Users/mayra/.local/lib/python3.9/site-packages/nilearn/glm/__init__.py:55: FutureWarning: The nilearn.glm module is experimental. It may change in any future release of Nilearn.
#   warn('The nilearn.glm module is experimental. '
# /Users/mayra/.local/lib/python3.9/site-packages/nilearn/glm/__init__.py:55: FutureWarning: The nilearn.glm module is experimental. It may change in any future release of Nilearn.
#   warn('The nilearn.glm module is experimental. '
# /Users/mayra/.local/lib/python3.9/site-packages/nilearn/glm/__init__.py:55: FutureWarning: The nilearn.glm module is experimental. It may change in any future release of Nilearn.
#   warn('The nilearn.glm module is experimental. '
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/model.py:315: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if current_hrf == 'direct':
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/model.py:315: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if current_hrf == 'direct':
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/model.py:315: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if current_hrf == 'direct':
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/model.py:315: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if current_hrf == 'direct':
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/model.py:315: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if current_hrf == 'direct':
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/model.py:315: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if current_hrf == 'direct':
# /Users/mayra/anaconda3/envs/prfpy_env/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# /Users/mayra/anaconda3/envs/prfpy_env/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# /Users/mayra/anaconda3/envs/prfpy_env/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# /Users/mayra/anaconda3/envs/prfpy_env/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# /Users/mayra/anaconda3/envs/prfpy_env/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# /Users/mayra/anaconda3/envs/prfpy_env/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed: 14.6min
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 100, function evaluations: 768, CG iterations: 382, optimality: 1.66e+01, constraint violation: 0.00e+00, execution time:  8.9 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 237, function evaluations: 1992, CG iterations: 1001, optimality: 5.76e+00, constraint violation: 0.00e+00, execution time: 2.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 118, function evaluations: 976, CG iterations: 484, optimality: 1.49e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 101, function evaluations: 944, CG iterations: 398, optimality: 4.61e-01, constraint violation: 0.00e+00, execution time: 1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 198, function evaluations: 2024, CG iterations: 758, optimality: 5.35e+00, constraint violation: 0.00e+00, execution time: 2.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 88, function evaluations: 784, CG iterations: 324, optimality: 2.62e+01, constraint violation: 0.00e+00, execution time:  8.6 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 99, function evaluations: 896, CG iterations: 364, optimality: 2.20e+00, constraint violation: 0.00e+00, execution time:  9.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 69, function evaluations: 472, CG iterations: 258, optimality: 6.79e-01, constraint violation: 0.00e+00, execution time:  5.2 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 62, function evaluations: 536, CG iterations: 214, optimality: 1.40e+01, constraint violation: 0.00e+00, execution time:  6.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 108, function evaluations: 920, CG iterations: 434, optimality: 6.14e+00, constraint violation: 0.00e+00, execution time: 1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 163, function evaluations: 1440, CG iterations: 594, optimality: 5.76e+00, constraint violation: 0.00e+00, execution time: 1.6e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 200, function evaluations: 1744, CG iterations: 813, optimality: 9.78e-01, constraint violation: 0.00e+00, execution time: 1.9e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 95, function evaluations: 752, CG iterations: 382, optimality: 8.56e-01, constraint violation: 0.00e+00, execution time:  8.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 208, function evaluations: 2088, CG iterations: 788, optimality: 2.05e+01, constraint violation: 0.00e+00, execution time: 2.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 83, function evaluations: 664, CG iterations: 354, optimality: 3.33e+00, constraint violation: 0.00e+00, execution time:  7.3 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 66, function evaluations: 632, CG iterations: 230, optimality: 7.43e+00, constraint violation: 0.00e+00, execution time:  6.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 53, function evaluations: 272, CG iterations: 147, optimality: 2.22e+01, constraint violation: 0.00e+00, execution time:  3.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 129, function evaluations: 1072, CG iterations: 512, optimality: 7.36e+01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 144, function evaluations: 1144, CG iterations: 569, optimality: 2.97e+01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 99, function evaluations: 800, CG iterations: 395, optimality: 2.34e+02, constraint violation: 0.00e+00, execution time:  9.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 94, function evaluations: 832, CG iterations: 375, optimality: 3.58e+00, constraint violation: 0.00e+00, execution time:  9.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 107, function evaluations: 1048, CG iterations: 393, optimality: 3.34e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 86, function evaluations: 824, CG iterations: 342, optimality: 1.14e+00, constraint violation: 0.00e+00, execution time:  9.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 77, function evaluations: 672, CG iterations: 295, optimality: 1.84e+00, constraint violation: 0.00e+00, execution time:  7.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 107, function evaluations: 1080, CG iterations: 399, optimality: 3.03e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 119, function evaluations: 888, CG iterations: 435, optimality: 9.20e+00, constraint violation: 0.00e+00, execution time:  9.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 121, function evaluations: 1000, CG iterations: 462, optimality: 1.58e+02, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 137, function evaluations: 1104, CG iterations: 526, optimality: 3.24e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 69, function evaluations: 440, CG iterations: 244, optimality: 5.02e+00, constraint violation: 0.00e+00, execution time:  4.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 126, function evaluations: 968, CG iterations: 487, optimality: 3.19e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 105, function evaluations: 928, CG iterations: 381, optimality: 2.41e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 145, function evaluations: 1208, CG iterations: 582, optimality: 2.35e+01, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 117, function evaluations: 1120, CG iterations: 464, optimality: 2.09e+02, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 111, function evaluations: 1120, CG iterations: 446, optimality: 2.52e+02, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 144, function evaluations: 1216, CG iterations: 587, optimality: 2.07e+00, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 185, function evaluations: 1696, CG iterations: 827, optimality: 2.26e+00, constraint violation: 0.00e+00, execution time: 2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 102, function evaluations: 776, CG iterations: 385, optimality: 1.07e+00, constraint violation: 0.00e+00, execution time:  8.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 153, function evaluations: 1256, CG iterations: 587, optimality: 3.38e-01, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 63, function evaluations: 480, CG iterations: 221, optimality: 4.40e+01, constraint violation: 0.00e+00, execution time:  6.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 110, function evaluations: 1128, CG iterations: 418, optimality: 1.02e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 520, CG iterations: 227, optimality: 8.64e+01, constraint violation: 0.00e+00, execution time:  5.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 157, function evaluations: 1360, CG iterations: 619, optimality: 2.11e+01, constraint violation: 0.00e+00, execution time: 1.7e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 87, function evaluations: 768, CG iterations: 358, optimality: 3.94e+01, constraint violation: 0.00e+00, execution time:  9.2 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 125, function evaluations: 960, CG iterations: 486, optimality: 4.84e+01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 128, function evaluations: 1104, CG iterations: 509, optimality: 1.32e+01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 87, function evaluations: 928, CG iterations: 200, optimality: 2.47e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 126, function evaluations: 1216, CG iterations: 403, optimality: 1.24e+00, constraint violation: 0.00e+00, execution time: 1.6e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 736, CG iterations: 225, optimality: 1.42e+00, constraint violation: 0.00e+00, execution time:  9.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 114, function evaluations: 1120, CG iterations: 323, optimality: 1.05e+01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 64, function evaluations: 672, CG iterations: 198, optimality: 1.88e+01, constraint violation: 0.00e+00, execution time:  7.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 704, CG iterations: 219, optimality: 4.70e+00, constraint violation: 0.00e+00, execution time:  7.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 83, function evaluations: 752, CG iterations: 313, optimality: 2.38e+01, constraint violation: 0.00e+00, execution time:  8.2 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 432, CG iterations: 234, optimality: 4.11e+01, constraint violation: 0.00e+00, execution time:  4.6 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 167, function evaluations: 1664, CG iterations: 636, optimality: 7.12e+00, constraint violation: 0.00e+00, execution time: 1.9e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 544, CG iterations: 246, optimality: 8.86e+01, constraint violation: 0.00e+00, execution time:  6.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 174, function evaluations: 1632, CG iterations: 512, optimality: 1.72e+00, constraint violation: 0.00e+00, execution time: 1.7e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 106, function evaluations: 1016, CG iterations: 384, optimality: 3.10e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 696, CG iterations: 212, optimality: 2.27e-01, constraint violation: 0.00e+00, execution time:  7.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 728, CG iterations: 269, optimality: 1.53e+00, constraint violation: 0.00e+00, execution time:  7.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 105, function evaluations: 1056, CG iterations: 347, optimality: 7.40e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 204, function evaluations: 1936, CG iterations: 689, optimality: 5.08e-01, constraint violation: 0.00e+00, execution time: 2.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 121, function evaluations: 1040, CG iterations: 445, optimality: 1.54e+01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 56, function evaluations: 632, CG iterations: 203, optimality: 3.72e+01, constraint violation: 0.00e+00, execution time:  6.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 99, function evaluations: 800, CG iterations: 381, optimality: 5.48e+01, constraint violation: 0.00e+00, execution time:  9.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 106, function evaluations: 1032, CG iterations: 415, optimality: 1.47e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 148, function evaluations: 1456, CG iterations: 577, optimality: 9.92e+00, constraint violation: 0.00e+00, execution time: 1.6e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 285, function evaluations: 2464, CG iterations: 1064, optimality: 9.11e-01, constraint violation: 0.00e+00, execution time: 2.7e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 128, function evaluations: 1032, CG iterations: 483, optimality: 1.70e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 58, function evaluations: 384, CG iterations: 167, optimality: 1.37e+01, constraint violation: 0.00e+00, execution time:  4.2 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 135, function evaluations: 1320, CG iterations: 517, optimality: 6.17e+00, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 85, function evaluations: 688, CG iterations: 322, optimality: 7.55e+00, constraint violation: 0.00e+00, execution time:  7.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 233, function evaluations: 1976, CG iterations: 939, optimality: 3.79e-01, constraint violation: 0.00e+00, execution time: 2.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 432, CG iterations: 218, optimality: 6.31e+00, constraint violation: 0.00e+00, execution time:  4.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 432, CG iterations: 225, optimality: 1.26e+00, constraint violation: 0.00e+00, execution time:  4.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 107, function evaluations: 864, CG iterations: 415, optimality: 5.82e-01, constraint violation: 0.00e+00, execution time:  9.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 103, function evaluations: 808, CG iterations: 344, optimality: 6.78e-01, constraint violation: 0.00e+00, execution time:  8.9 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 157, function evaluations: 1376, CG iterations: 521, optimality: 7.66e-01, constraint violation: 0.00e+00, execution time: 1.6e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 66, function evaluations: 632, CG iterations: 245, optimality: 1.17e+00, constraint violation: 0.00e+00, execution time:  7.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 189, function evaluations: 1736, CG iterations: 788, optimality: 4.90e+00, constraint violation: 0.00e+00, execution time: 1.9e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 147, function evaluations: 1448, CG iterations: 597, optimality: 7.27e-01, constraint violation: 0.00e+00, execution time: 1.6e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 194, function evaluations: 1624, CG iterations: 823, optimality: 9.75e+01, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 86, function evaluations: 680, CG iterations: 346, optimality: 3.01e+00, constraint violation: 0.00e+00, execution time:  7.6 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 128, function evaluations: 1176, CG iterations: 539, optimality: 5.78e+02, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 69, function evaluations: 808, CG iterations: 273, optimality: 3.25e+00, constraint violation: 0.00e+00, execution time:  8.6 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 121, function evaluations: 1168, CG iterations: 446, optimality: 1.15e+00, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 132, function evaluations: 976, CG iterations: 521, optimality: 5.37e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 175, function evaluations: 1688, CG iterations: 665, optimality: 1.03e+00, constraint violation: 0.00e+00, execution time: 1.9e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 105, function evaluations: 792, CG iterations: 417, optimality: 9.07e+01, constraint violation: 0.00e+00, execution time:  8.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 119, function evaluations: 976, CG iterations: 467, optimality: 6.84e+01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 77, function evaluations: 576, CG iterations: 298, optimality: 3.79e+01, constraint violation: 0.00e+00, execution time:  6.3 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 89, function evaluations: 736, CG iterations: 353, optimality: 4.00e+00, constraint violation: 0.00e+00, execution time:  9.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 520, CG iterations: 251, optimality: 3.91e+00, constraint violation: 0.00e+00, execution time:  5.9 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 157, function evaluations: 1344, CG iterations: 587, optimality: 3.94e+00, constraint violation: 0.00e+00, execution time: 1.6e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 112, function evaluations: 1144, CG iterations: 445, optimality: 1.87e+00, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 115, function evaluations: 984, CG iterations: 508, optimality: 3.24e+01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 120, function evaluations: 984, CG iterations: 483, optimality: 1.18e+01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 101, function evaluations: 1000, CG iterations: 360, optimality: 4.68e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 146, function evaluations: 1400, CG iterations: 532, optimality: 1.20e-01, constraint violation: 0.00e+00, execution time: 1.7e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 54, function evaluations: 512, CG iterations: 177, optimality: 1.31e+00, constraint violation: 0.00e+00, execution time:  6.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 145, function evaluations: 1112, CG iterations: 559, optimality: 4.14e-01, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 116, function evaluations: 1056, CG iterations: 306, optimality: 4.38e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 536, CG iterations: 277, optimality: 1.78e+01, constraint violation: 0.00e+00, execution time:  6.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 114, function evaluations: 928, CG iterations: 414, optimality: 3.88e+01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 146, function evaluations: 1160, CG iterations: 573, optimality: 2.70e+00, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 62, function evaluations: 488, CG iterations: 239, optimality: 2.57e+00, constraint violation: 0.00e+00, execution time:  5.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 163, function evaluations: 1408, CG iterations: 671, optimality: 5.05e+00, constraint violation: 0.00e+00, execution time: 1.7e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 184, function evaluations: 1768, CG iterations: 676, optimality: 6.00e+00, constraint violation: 0.00e+00, execution time: 2.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 93, function evaluations: 872, CG iterations: 341, optimality: 8.72e-02, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 346, function evaluations: 3120, CG iterations: 1160, optimality: 1.01e+01, constraint violation: 0.00e+00, execution time: 3.7e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 624, CG iterations: 284, optimality: 3.71e+00, constraint violation: 0.00e+00, execution time:  6.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 73, function evaluations: 640, CG iterations: 220, optimality: 6.64e-01, constraint violation: 0.00e+00, execution time:  6.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 111, function evaluations: 1064, CG iterations: 374, optimality: 7.12e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 133, function evaluations: 1072, CG iterations: 523, optimality: 8.99e-01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 119, function evaluations: 1016, CG iterations: 475, optimality: 2.52e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 77, function evaluations: 664, CG iterations: 292, optimality: 2.02e+00, constraint violation: 0.00e+00, execution time:  7.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 94, function evaluations: 720, CG iterations: 365, optimality: 1.08e+00, constraint violation: 0.00e+00, execution time:  7.6 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 79, function evaluations: 832, CG iterations: 272, optimality: 8.02e-01, constraint violation: 0.00e+00, execution time:  8.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 79, function evaluations: 760, CG iterations: 271, optimality: 2.88e+00, constraint violation: 0.00e+00, execution time:  8.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 77, function evaluations: 680, CG iterations: 219, optimality: 3.23e+00, constraint violation: 0.00e+00, execution time:  7.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 180, function evaluations: 1640, CG iterations: 652, optimality: 1.24e+00, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 64, function evaluations: 712, CG iterations: 190, optimality: 3.89e-01, constraint violation: 0.00e+00, execution time:  7.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 93, function evaluations: 928, CG iterations: 323, optimality: 5.39e+00, constraint violation: 0.00e+00, execution time:  9.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 85, function evaluations: 752, CG iterations: 267, optimality: 5.40e-01, constraint violation: 0.00e+00, execution time:  7.9 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 64, function evaluations: 384, CG iterations: 234, optimality: 3.74e+00, constraint violation: 0.00e+00, execution time:  4.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 131, function evaluations: 1160, CG iterations: 519, optimality: 1.10e+01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 103, function evaluations: 832, CG iterations: 406, optimality: 1.16e+01, constraint violation: 0.00e+00, execution time:  8.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 50, function evaluations: 232, CG iterations: 171, optimality: 4.10e+00, constraint violation: 0.00e+00, execution time:  2.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 150, function evaluations: 1320, CG iterations: 592, optimality: 2.56e+01, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 123, function evaluations: 952, CG iterations: 497, optimality: 5.20e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 98, function evaluations: 960, CG iterations: 365, optimality: 7.40e+00, constraint violation: 0.00e+00, execution time: 1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 197, function evaluations: 1648, CG iterations: 818, optimality: 7.54e+00, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 150, function evaluations: 1208, CG iterations: 597, optimality: 2.28e+00, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 103, function evaluations: 872, CG iterations: 395, optimality: 3.36e+00, constraint violation: 0.00e+00, execution time:  9.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 148, function evaluations: 1304, CG iterations: 613, optimality: 4.26e-01, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 114, function evaluations: 1056, CG iterations: 425, optimality: 7.32e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 132, function evaluations: 1112, CG iterations: 520, optimality: 5.08e-01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 100, function evaluations: 920, CG iterations: 397, optimality: 3.59e+00, constraint violation: 0.00e+00, execution time: 1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 150, function evaluations: 1256, CG iterations: 582, optimality: 2.76e+01, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 70, function evaluations: 664, CG iterations: 251, optimality: 7.39e+00, constraint violation: 0.00e+00, execution time:  7.2 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 99, function evaluations: 920, CG iterations: 395, optimality: 9.03e-01, constraint violation: 0.00e+00, execution time: 1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 111, function evaluations: 1088, CG iterations: 440, optimality: 9.91e-01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 111, function evaluations: 856, CG iterations: 439, optimality: 5.01e-01, constraint violation: 0.00e+00, execution time:  9.6 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 199, function evaluations: 1624, CG iterations: 800, optimality: 2.14e+00, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 83, function evaluations: 760, CG iterations: 318, optimality: 8.44e-01, constraint violation: 0.00e+00, execution time:  8.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 97, function evaluations: 760, CG iterations: 370, optimality: 1.22e+00, constraint violation: 0.00e+00, execution time:  8.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 103, function evaluations: 808, CG iterations: 390, optimality: 7.47e+01, constraint violation: 0.00e+00, execution time:  9.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 99, function evaluations: 1000, CG iterations: 382, optimality: 2.25e+02, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 183, function evaluations: 1544, CG iterations: 731, optimality: 1.64e+01, constraint violation: 0.00e+00, execution time: 1.7e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 136, function evaluations: 1360, CG iterations: 503, optimality: 1.30e+00, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 111, function evaluations: 880, CG iterations: 426, optimality: 2.74e+02, constraint violation: 0.00e+00, execution time:  9.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 135, function evaluations: 1136, CG iterations: 542, optimality: 1.05e+02, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 66, function evaluations: 552, CG iterations: 242, optimality: 1.18e+00, constraint violation: 0.00e+00, execution time:  6.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 176, function evaluations: 1752, CG iterations: 655, optimality: 9.15e+00, constraint violation: 0.00e+00, execution time: 1.9e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 136, function evaluations: 1112, CG iterations: 518, optimality: 1.21e+00, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 162, function evaluations: 1304, CG iterations: 664, optimality: 2.22e+00, constraint violation: 0.00e+00, execution time: 1.6e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 109, function evaluations: 912, CG iterations: 419, optimality: 7.79e+01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 165, function evaluations: 1624, CG iterations: 645, optimality: 1.72e+00, constraint violation: 0.00e+00, execution time: 1.9e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 104, function evaluations: 952, CG iterations: 423, optimality: 1.07e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 95, function evaluations: 944, CG iterations: 349, optimality: 9.66e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 94, function evaluations: 920, CG iterations: 351, optimality: 1.22e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 124, function evaluations: 1224, CG iterations: 387, optimality: 1.97e+00, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 115, function evaluations: 1048, CG iterations: 427, optimality: 7.06e-01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 120, function evaluations: 976, CG iterations: 465, optimality: 8.39e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 91, function evaluations: 960, CG iterations: 341, optimality: 8.21e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 125, function evaluations: 968, CG iterations: 498, optimality: 7.25e-01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# ...
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 66, function evaluations: 632, CG iterations: 202, optimality: 6.26e+00, constraint violation: 0.00e+00, execution time:  6.2 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 135, function evaluations: 1280, CG iterations: 411, optimality: 3.97e-01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 184, function evaluations: 1776, CG iterations: 649, optimality: 9.07e-02, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 73, function evaluations: 848, CG iterations: 276, optimality: 9.00e-01, constraint violation: 0.00e+00, execution time:  8.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 116, function evaluations: 1144, CG iterations: 489, optimality: 3.01e+01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 188, function evaluations: 1960, CG iterations: 576, optimality: 9.51e-02, constraint violation: 0.00e+00, execution time: 2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 79, function evaluations: 888, CG iterations: 306, optimality: 1.30e+00, constraint violation: 0.00e+00, execution time:  8.9 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 90, function evaluations: 904, CG iterations: 316, optimality: 1.09e+01, constraint violation: 0.00e+00, execution time:  9.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 152, function evaluations: 1512, CG iterations: 595, optimality: 1.10e-01, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 173, function evaluations: 1784, CG iterations: 631, optimality: 1.41e-01, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 97, function evaluations: 936, CG iterations: 270, optimality: 1.82e-01, constraint violation: 0.00e+00, execution time:  9.3 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 233, function evaluations: 2096, CG iterations: 745, optimality: 4.14e-01, constraint violation: 0.00e+00, execution time: 2.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 195, function evaluations: 1800, CG iterations: 755, optimality: 6.64e+00, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 536, CG iterations: 236, optimality: 1.22e+01, constraint violation: 0.00e+00, execution time:  5.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 92, function evaluations: 792, CG iterations: 348, optimality: 1.18e-01, constraint violation: 0.00e+00, execution time:  8.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 88, function evaluations: 840, CG iterations: 247, optimality: 9.89e-02, constraint violation: 0.00e+00, execution time:  8.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 568, CG iterations: 247, optimality: 2.24e+01, constraint violation: 0.00e+00, execution time:  5.9 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 93, function evaluations: 824, CG iterations: 283, optimality: 7.52e-01, constraint violation: 0.00e+00, execution time:  8.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 149, function evaluations: 1496, CG iterations: 594, optimality: 2.59e+01, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 159, function evaluations: 1448, CG iterations: 590, optimality: 9.63e-02, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 120, function evaluations: 1320, CG iterations: 391, optimality: 1.47e+00, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 152, function evaluations: 1480, CG iterations: 426, optimality: 3.93e-02, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 196, function evaluations: 1864, CG iterations: 710, optimality: 5.60e-01, constraint violation: 0.00e+00, execution time: 1.9e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 138, function evaluations: 1256, CG iterations: 486, optimality: 5.90e-01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 181, function evaluations: 1776, CG iterations: 536, optimality: 1.26e+00, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 103, function evaluations: 1096, CG iterations: 365, optimality: 6.64e+01, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 325, function evaluations: 2880, CG iterations: 1355, optimality: 1.07e+00, constraint violation: 0.00e+00, execution time: 3.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 91, function evaluations: 1008, CG iterations: 281, optimality: 2.19e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 91, function evaluations: 816, CG iterations: 318, optimality: 1.47e+00, constraint violation: 0.00e+00, execution time:  9.1 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 109, function evaluations: 872, CG iterations: 425, optimality: 2.47e+01, constraint violation: 0.00e+00, execution time:  9.7 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 96, function evaluations: 920, CG iterations: 337, optimality: 3.64e+00, constraint violation: 0.00e+00, execution time:  9.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 179, function evaluations: 1488, CG iterations: 675, optimality: 2.15e+01, constraint violation: 0.00e+00, execution time: 1.6e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 56, function evaluations: 704, CG iterations: 177, optimality: 3.39e+00, constraint violation: 0.00e+00, execution time:  7.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 78, function evaluations: 800, CG iterations: 216, optimality: 1.60e+00, constraint violation: 0.00e+00, execution time:  8.9 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 688, CG iterations: 228, optimality: 6.02e-01, constraint violation: 0.00e+00, execution time:  6.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 127, function evaluations: 1296, CG iterations: 464, optimality: 1.95e-01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 117, function evaluations: 1152, CG iterations: 384, optimality: 1.33e+01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 239, function evaluations: 2232, CG iterations: 816, optimality: 8.27e+00, constraint violation: 0.00e+00, execution time: 2.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 157, function evaluations: 1520, CG iterations: 647, optimality: 1.96e+00, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 149, function evaluations: 1472, CG iterations: 523, optimality: 1.76e-01, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 129, function evaluations: 1264, CG iterations: 446, optimality: 5.88e+00, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 69, function evaluations: 728, CG iterations: 191, optimality: 7.62e+00, constraint violation: 0.00e+00, execution time:  7.3 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 78, function evaluations: 856, CG iterations: 236, optimality: 5.09e+00, constraint violation: 0.00e+00, execution time:  8.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 138, function evaluations: 1304, CG iterations: 506, optimality: 2.77e-01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 119, function evaluations: 1184, CG iterations: 450, optimality: 2.76e-02, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 110, function evaluations: 1144, CG iterations: 350, optimality: 2.03e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 109, function evaluations: 944, CG iterations: 416, optimality: 3.00e-01, constraint violation: 0.00e+00, execution time:  9.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 74, function evaluations: 632, CG iterations: 294, optimality: 5.16e-02, constraint violation: 0.00e+00, execution time:  6.4 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 178, function evaluations: 1776, CG iterations: 700, optimality: 9.70e-01, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 149, function evaluations: 1360, CG iterations: 477, optimality: 1.22e+01, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 118, function evaluations: 1152, CG iterations: 359, optimality: 4.14e-01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 792, CG iterations: 205, optimality: 6.30e-01, constraint violation: 0.00e+00, execution time:  8.0 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 91, function evaluations: 920, CG iterations: 276, optimality: 1.20e+00, constraint violation: 0.00e+00, execution time:  9.2 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 212, function evaluations: 2032, CG iterations: 715, optimality: 2.20e+00, constraint violation: 0.00e+00, execution time: 2.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 128, function evaluations: 1240, CG iterations: 421, optimality: 7.74e-02, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 114, function evaluations: 1024, CG iterations: 486, optimality: 3.51e+00, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 81, function evaluations: 824, CG iterations: 237, optimality: 1.83e-01, constraint violation: 0.00e+00, execution time:  8.5 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 141, function evaluations: 1512, CG iterations: 437, optimality: 1.49e-01, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 173, function evaluations: 1672, CG iterations: 696, optimality: 5.77e+00, constraint violation: 0.00e+00, execution time: 1.7e+01 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 86, function evaluations: 864, CG iterations: 255, optimality: 9.64e-01, constraint violation: 0.00e+00, execution time:  8.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# Number of iterations: 77, function evaluations: 760, CG iterations: 231, optimality: 3.82e-01, constraint violation: 0.00e+00, execution time:  7.8 s.
# Performing bounded, constrained minimization (trust-constr).
# `xtol` termination condition is satisfied.
# [Parallel(n_jobs=6)]: Done 22835 out of 22835 | elapsed: 761.1min finished

# %%
print(f'Min rsq = {np.nanmin(gauss_fitter.iterative_search_params[gauss_fitter.rsq_mask!=0,-1]):.3f}')
print(f'Mean rsq = {np.nanmean(gauss_fitter.iterative_search_params[gauss_fitter.rsq_mask>0,-1]):.3f}')
print(f'Max rsq = {gauss_fitter.iterative_search_params[:,-1].max():.3f}')
print(np.where(gauss_fitter.iterative_search_params[:,-1]==gauss_fitter.iterative_search_params[:,-1].max()))

# Plot the location...
plt.scatter(gauss_fitter.iterative_search_params[:,0], gauss_fitter.iterative_search_params[:,1],marker='o', s=2)
plt.xlim(-5,5)
plt.ylim(-5,5)
# Out:
# Min rsq = 0.011
# Mean rsq = 0.236
# Max rsq = 0.761
# (array([14569]),)
# (-5.0, 5.0)

# %%
best_vx=np.where(gauss_fitter.iterative_search_params[:,-1]==gauss_fitter.iterative_search_params[:,-1].max())
best_vx
# Out:
# (array([14569]),)

# %% [markdown]
# # WELL DONE!
# We now have a set of prf fits.

# %%
# We can now create the predicted timeseries, and compare these with the data

prf_params = gauss_fitter.iterative_search_params
pred_tc=gauss_model.return_prediction(
    mu_x = prf_params[:,0], # x position
    mu_y = prf_params[:,1], # y position
    size = prf_params[:,2], # prf size
    beta = prf_params[:,3], # prf amplitude
    baseline = prf_params[:,4], # prf baseline (set to 0)
    hrf_1 = prf_params[:,5],
    hrf_2 = prf_params[:,6],
)
# Out:
# /Users/mayra/PycharmProjects/Github/prfpy/prfpy/rf.py:112: RuntimeWarning: divide by zero encountered in divide
#   return (np.exp(-((x-mu[0])**2 + (y-mu[1])**2)/(2*sigma**2))).astype('float32')

# %% [markdown]
# Have a look at the model fits:
# * vary the voxel you are looking at (i_vx)
# * also look at how the parameters (in the title), determine the location and size of the RF
# * varying "time_pt", you can see where the stimulus is, at different times
# * Note that the HRF means that responses of the model will be delayed...

# %%
TR_s = prf_settings['TR']
fig = plt.figure(constrained_layout=True, figsize=(30,10))
subfigs = fig.subfigures(1, 2, width_ratios=[10,30])
i_vx = int(best_vx[0])
#i_vx=24798

# ************* TIME COURSE PLOT *************
time_pts = np.arange(psc_avg_ts.shape[1]) * TR_s    
ax2 = subfigs[1].add_subplot()
ax2.plot(time_pts, psc_avg_ts[i_vx,:], '-+k', label= 'data')
ax2.plot(time_pts, pred_tc[i_vx,:], '-*r', label= 'pred')
# ax2.plot(time_pts, pred_tc_nohrf[i_vx,:], '-*b', label= 'pred_nohrf')
ax2.set_xlabel('time (s)')
ax2.legend()
ax2.set_ylim([-10,10])
plt.rcParams.update({'font.size': 22})


gauss_param_name = ['x', 'y', 'size', 'beta', 'baseline', 'hrf_der','hrf_disp','rsq']
title_txt = ''
for i,p in enumerate(gauss_param_name):
    title_txt += f'{p}={prf_params[i_vx,i]:.3f},'
ax2.set_title(title_txt)

# ********* PRF PLOT **********
rf = gauss2D_iso_cart(
    x=prf_stim.x_coordinates,
    y=prf_stim.y_coordinates,
    mu=(prf_params[i_vx,0], prf_params[i_vx,1]),
    sigma=prf_params[i_vx,2])
ax1 = subfigs[0].add_subplot()
ax1.imshow(rf, vmin=0, vmax=1, extent=[-5,5,-5,5])
ax1.axis('off')

time_pt = 90
if time_pt != None:
    ax1.imshow(dm[:,:,time_pt], vmin=0, vmax=1,cmap='Greys', alpha=0.1, extent=[-5,5,-5,5])
    ax_lim = ax2.get_ylim()
    ax2.plot((time_pt*TR_s, time_pt*TR_s), (ax_lim), '--g')

ax2.set_xticks(np.arange(time_pts[0], time_pts[-1],10))
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=22)
add_dm_to_ts(fig, ax2, dm, TR=TR_s, dx_axs=2)

# %%
print(f'Mean r2= {np.nanmean(gauss_fitter.iterative_search_params[gauss_fitter.rsq_mask!=0,7]):.3f}')
print(f'Min r2= {np.min(gauss_fitter.iterative_search_params[gauss_fitter.rsq_mask==1,7]):.3f}')
print(f'Max r2= {np.max(gauss_fitter.iterative_search_params[gauss_fitter.rsq_mask!=0,7]):.3f}')
plt.hist(gauss_fitter.iterative_search_params[gauss_fitter.rsq_mask!=0,7])
plt.show()
plt.hist(gauss_fitter.iterative_search_params[gauss_fitter.rsq_mask!=0,2])
print(f'Best vx hrf_deriv= {gauss_fitter.iterative_search_params[int(best_vx[0]),-3]:.3f}')
print(f'Best vx size= {gauss_fitter.iterative_search_params[int(best_vx[0]),2]:.3f}')
print(f'Best vx r2 no_hrf_grid= {gauss_fitter.gridsearch_params[int(best_vx[0]),-1]:.3f}')
print(f'Best vx r2 no_hrf_iter= {gauss_fitter.iterative_search_params[int(best_vx[0]),-1]:.3f}')
print(f'Best vx r2 iter= {gauss_fitter.iterative_search_params[int(best_vx[0]),-1]:.3f}')

print(f'Nvx = {np.count_nonzero(gauss_fitter.rsq_mask)} out of {rsq_mask.shape[0]}, {np.count_nonzero(gauss_fitter.rsq_mask)/rsq_mask.shape[0]*100:.1f}%')
# Out:
# Mean r2= 0.236
# Min r2= 0.011
# Max r2= 0.761
# Best vx hrf_deriv= 9.998
# Best vx size= 0.971
# Best vx r2 no_hrf_grid= 0.757
# Best vx r2 no_hrf_iter= 0.761
# Best vx r2 iter= 0.761
# Nvx = 22835 out of 22862, 99.9%

# %%
import pickle
def save_params(model, model_name):

    if rois.__len__()==1:
        pkl_file = opj(f'{MAIN_PATH}/pRFM/{subject}/ses-1/{denoising}/', f'roi-{rois[0]}_model-{atlas}-{model_name}-{depth}_desc-prf_params.pkl')
    else:
        pkl_file = opj(f'{MAIN_PATH}/pRFM/{subject}/ses-1/{denoising}/', f'model-{atlas}-{model_name}-{depth}_desc-prf_params.pkl')

    # get parameters given model and stage
    model=model
    settings = prf_settings
    prf_params = model.iterative_search_params
    pred_tc = gauss_model.return_prediction(
    mu_x = prf_params[:,0], # x position
    mu_y = prf_params[:,1], # y position
    size = prf_params[:,2], # prf size
    beta = prf_params[:,3], # prf amplitude
    baseline = prf_params[:,4], # prf baseline (set to 0)
    hrf_1 = prf_params[:,5],
    hrf_2 = prf_params[:,6],
    )

    # write a pickle-file with relevant outputs
    out_dict = {}
    out_dict['model'] = model
    out_dict['settings'] = settings
    out_dict['pred_tc'] = pred_tc
    out_dict['rois_mask'] = rois_mask.data
    if rois.__len__()==1:
        out_dict['roi_verts'] = roi_verts

    f = open(pkl_file, "wb")
    pickle.dump(out_dict, f)
    f.close()

# %%
save_params(gauss_fitter, 'gauss_fitter')
